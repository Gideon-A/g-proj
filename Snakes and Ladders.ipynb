# %%
# 1)

# %%
import random

# Using dictionaries to store the snakes and ladders on the board
# ladders move you up from the key to value
# Snakes move you down from the key to value
ladders = {7: 14,
    15: 21,
    20: 29,
    27: 31,
    35: 39,
    40: 54,
    63: 72,
    67: 80,
    70: 74,
    75: 90,}

snakes = {10: 2,
    12: 9,
    18: 13,
    26: 22,
    30: 28,
    39: 34,
    61: 55,
    73: 68,
    78: 69,
    99: 81,}

max_num = 100

def welcome_msg():
    """Start message explain the rules"""
    msg = """Welcome to Snakes and Ladders
    Rules:
    Two players
    Take turns to roll a six sided dice and move forward the number of positions shown on the dice
    Start at position 0
    The first player that reaches the final spot, 100, wins the game
    A cell on the board cannot contain both a snake and a ladder
    If you land at the bottom of the ladder you move to the top of the ladder
    If you land on the head of the snake you must slide down to the tail of the snake"""
    print(msg)

def player_name():
    """Establishing player name"""
    player_1_name = ("Player A")
    player_2_name = ("Player B")
    print(player_1_name, "vs", player_2_name)
    return player_1_name, player_2_name

def dice_num_roll():
    dice_num = random.randint(1, 6)
    print("        You rolled a ", str(dice_num))
    return dice_num

def snake_bite(old_num, curr_num, player_name):
    """When a player lands on a snake cell"""
    print("Unfortunately, you have landed on a snake, please go down")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))

def ladder_climb(old_num, curr_num, player_name):
    """When a player lands on a ladder cell"""
    print("Wooo, you have landed on a ladder, please climb up")
    print(player_name, "moved from", str(old_num), "to", str(curr_num)) 

def snakes_and_ladders_check(player_name, curr_num, dice_num):
    """A method that checks for the presence of snakes and ladders on the board"""
    old_num = curr_num # position on board
    curr_num = curr_num + dice_num # position on board plus the dice roll to give new position
    
    if curr_num > max_num: # when player rolls and goes over final number
        print("Unlucky, you need to roll a", str(max_num - old_num), "to win the game so dont give up, keep rolling.")
        return old_num
    print("                ", player_name, "moved from", str(old_num), "to", str(curr_num))
    if curr_num in snakes:
        final_num = snakes.get(curr_num) # Returns the value of the specified key
        snake_bite(curr_num, final_num, player_name)
    elif curr_num in ladders:
        final_num = ladders.get(curr_num)
        ladder_climb(curr_num, final_num, player_name)
    else:
        final_num = curr_num
    return final_num

def win_check(player_name, pos):
    """Checks if player has met the win criteria"""
    if max_num == pos:
        print("""Congrats""", player_name, """, you have won the game!""")
        raise SystemExit # to stop the code running thus ending the game

def start_game():
    """The function to run the program and start the game"""
    welcome_msg()
    player_1_name, player_2_name = player_name()
    player_1_curr_pos = 0
    player_2_curr_pos = 0
    while True:
        print(player_1_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        print("            ", player_1_name, "is currently moving....")
        player_1_curr_pos = snakes_and_ladders_check(player_1_name, player_1_curr_pos, dice_num)
        win_check(player_1_name, player_1_curr_pos)
        
        print(player_2_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        print("            ", player_2_name, "is currently moving....")
        player_2_curr_pos = snakes_and_ladders_check(player_2_name, player_2_curr_pos, dice_num)
        win_check(player_2_name, player_2_curr_pos)
        
start_game()
# Out:
# Welcome to Snakes and Ladders
#     Rules:
#     Two players
#     Take turns to roll a six sided dice and move forward the number of positions shown on the dice
#     Start at position 0
#     The first player that reaches the final spot, 100, wins the game
#     A cell on the board cannot contain both a snake and a ladder
#     If you land at the bottom of the ladder you move to the top of the ladder
#     If you land on the head of the snake you must slide down to the tail of the snake
# Player A vs Player B
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
#              Player A is currently moving....
#                  Player A moved from 0 to 4
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
#              Player B is currently moving....
#                  Player B moved from 0 to 6
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
#              Player A is currently moving....
#                  Player A moved from 4 to 9
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
#              Player B is currently moving....
#                  Player B moved from 6 to 9
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
#              Player A is currently moving....
#                  Player A moved from 9 to 11
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
#              Player B is currently moving....
#                  Player B moved from 9 to 11
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
#              Player A is currently moving....
#                  Player A moved from 11 to 15
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 15 to 21
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
#              Player B is currently moving....
#                  Player B moved from 11 to 12
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 12 to 9
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
#              Player A is currently moving....
#                  Player A moved from 21 to 22
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
#              Player B is currently moving....
#                  Player B moved from 9 to 14
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
#              Player A is currently moving....
#                  Player A moved from 22 to 25
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
#              Player B is currently moving....
#                  Player B moved from 14 to 18
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 18 to 13
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
#              Player A is currently moving....
#                  Player A moved from 25 to 27
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 27 to 31
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
#              Player B is currently moving....
#                  Player B moved from 13 to 19
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
#              Player A is currently moving....
#                  Player A moved from 31 to 36
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
#              Player B is currently moving....
#                  Player B moved from 19 to 22
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
#              Player A is currently moving....
#                  Player A moved from 36 to 39
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 39 to 34
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
#              Player B is currently moving....
#                  Player B moved from 22 to 28
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
#              Player A is currently moving....
#                  Player A moved from 34 to 40
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 40 to 54
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
#              Player B is currently moving....
#                  Player B moved from 28 to 30
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 30 to 28
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
#              Player A is currently moving....
#                  Player A moved from 54 to 59
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
#              Player B is currently moving....
#                  Player B moved from 28 to 29
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
#              Player A is currently moving....
#                  Player A moved from 59 to 61
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 61 to 55
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
#              Player B is currently moving....
#                  Player B moved from 29 to 33
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
#              Player A is currently moving....
#                  Player A moved from 55 to 56
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
#              Player B is currently moving....
#                  Player B moved from 33 to 38
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
#              Player A is currently moving....
#                  Player A moved from 56 to 59
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
#              Player B is currently moving....
#                  Player B moved from 38 to 41
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
#              Player A is currently moving....
#                  Player A moved from 59 to 62
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
#              Player B is currently moving....
#                  Player B moved from 41 to 42
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
#              Player A is currently moving....
#                  Player A moved from 62 to 64
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
#              Player B is currently moving....
#                  Player B moved from 42 to 48
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
#              Player A is currently moving....
#                  Player A moved from 64 to 65
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
#              Player B is currently moving....
#                  Player B moved from 48 to 50
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
#              Player A is currently moving....
#                  Player A moved from 65 to 67
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 67 to 80
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
#              Player B is currently moving....
#                  Player B moved from 50 to 54
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
#              Player A is currently moving....
#                  Player A moved from 80 to 83
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
#              Player B is currently moving....
#                  Player B moved from 54 to 55
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
#              Player A is currently moving....
#                  Player A moved from 83 to 84
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
#              Player B is currently moving....
#                  Player B moved from 55 to 60
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
#              Player A is currently moving....
#                  Player A moved from 84 to 90
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
#              Player B is currently moving....
#                  Player B moved from 60 to 61
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 61 to 55
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
#              Player A is currently moving....
#                  Player A moved from 90 to 91
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
#              Player B is currently moving....
#                  Player B moved from 55 to 61
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 61 to 55
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
#              Player A is currently moving....
#                  Player A moved from 91 to 93
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
#              Player B is currently moving....
#                  Player B moved from 55 to 61
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 61 to 55
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
#              Player A is currently moving....
#                  Player A moved from 93 to 98
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
#              Player B is currently moving....
#                  Player B moved from 55 to 58
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
#              Player A is currently moving....
# Unlucky, you need to roll a 2 to win the game so dont give up, keep rolling.
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
#              Player B is currently moving....
#                  Player B moved from 58 to 63
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 63 to 72
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
#              Player A is currently moving....
#                  Player A moved from 98 to 100
# Congrats Player A , you have won the game!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# Testing the code

# %%
import random

# Using dictionaries to store the snakes and ladders on the board
# ladders move you up from the key to value
# Snakes move you down from the key to value
ladders = {}

snakes = {}

max_num = 100

def welcome_msg():
    """Start message explain the rules"""
    msg = """Welcome to Snakes and Ladders
    Rules:
    Two players
    Take turns to roll a six sided dice and move forward the number of positions shown on the dice
    Start at position 0
    The first player that reaches the final spot, 100, wins the game
    A cell on the board cannot contain both a snake and a ladder
    If you land at the bottom of the ladder you move to the top of the ladder
    If you land on the head of the snake you must slide down to the tail of the snake"""
    print(msg)

def player_name():
    """Establishing player name"""
    player_1_name = ("Player A")
    player_2_name = ("Player B")
    print(player_1_name, "vs", player_2_name)
    return player_1_name, player_2_name

def dice_num_roll():
    dice_num = random.randint(1, 15)
    print("        You rolled a ", str(dice_num))
    return dice_num

def snake_bite(old_num, curr_num, player_name):
    """When a player lands on a snake cell"""    
    print("Unfortunately, you have landed on a snake, please go down")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))

def ladder_climb(old_num, curr_num, player_name):
    """When a player lands on a ladder cell"""
    print("Wooo, you have landed on a ladder, please climb up")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))
    

def snakes_and_ladders_check(player_name, curr_num, dice_num):
    """A method that checks for the presence of snakes and ladders on the board"""
    old_num = curr_num
    curr_num = curr_num + dice_num
    
    if curr_num > max_num:
        print("Unlucky, you need to roll a", str(max_num - old_num), "to win the game so don't give up, keep rolling.")
        return old_num
    
    print("                ", player_name, "moved from", str(old_num), "to", str(curr_num))
    if curr_num in snakes:
        final_num = snakes.get(curr_num) # Returns the value of the specified key
        snake_bite(curr_num, final_num, player_name)        
    elif curr_num in ladders:
        final_num = ladders.get(curr_num)
        ladder_climb(curr_num, final_num, player_name)
    else:
        final_num = curr_num

    return final_num

def win_check(player_name, pos):
    """Checks if player has met the win criteria"""
    if max_num == pos:
        print("""Congrats""", player_name, """, you have won the game!""")
        raise SystemExit # to stop the code running thus ending the game 

def start_game():
    """The function to run the program and start the game"""
    welcome_msg()
    player_1_name, player_2_name = player_name()
    
    player_1_curr_pos = 0
    player_2_curr_pos = 0
    
    player_A_roll_count = 0
    player_B_roll_count = 0
    
    while True:
        print(player_1_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        player_A_roll_count = player_A_roll_count + 1
        print("--Player A has rolled the dice", player_A_roll_count, "times--")
        print("            ", player_1_name, "is currently moving....")
        player_1_curr_pos = snakes_and_ladders_check(player_1_name, player_1_curr_pos, dice_num)
        win_check(player_1_name, player_1_curr_pos)
        
        print(player_2_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        player_B_roll_count = player_B_roll_count + 1
        print("--Player B has rolled the dice", player_B_roll_count, "times--")
        print("            ", player_2_name, "is currently moving....")
        player_2_curr_pos = snakes_and_ladders_check(player_2_name, player_2_curr_pos, dice_num)
        win_check(player_2_name, player_2_curr_pos)       

start_game()
# Out:
# Welcome to Snakes and Ladders
#     Rules:
#     Two players
#     Take turns to roll a six sided dice and move forward the number of positions shown on the dice
#     Start at position 0
#     The first player that reaches the final spot, 100, wins the game
#     A cell on the board cannot contain both a snake and a ladder
#     If you land at the bottom of the ladder you move to the top of the ladder
#     If you land on the head of the snake you must slide down to the tail of the snake
# Player A vs Player B
# Player A its your turn
#     Rolling dice...
#         You rolled a  14
# --Player A has rolled the dice 1 times--
#              Player A is currently moving....
#                  Player A moved from 0 to 14
# Player B its your turn
#     Rolling dice...
#         You rolled a  11
# --Player B has rolled the dice 1 times--
#              Player B is currently moving....
#                  Player B moved from 0 to 11
# Player A its your turn
#     Rolling dice...
#         You rolled a  8
# --Player A has rolled the dice 2 times--
#              Player A is currently moving....
#                  Player A moved from 14 to 22
# Player B its your turn
#     Rolling dice...
#         You rolled a  7
# --Player B has rolled the dice 2 times--
#              Player B is currently moving....
#                  Player B moved from 11 to 18
# Player A its your turn
#     Rolling dice...
#         You rolled a  11
# --Player A has rolled the dice 3 times--
#              Player A is currently moving....
#                  Player A moved from 22 to 33
# Player B its your turn
#     Rolling dice...
#         You rolled a  10
# --Player B has rolled the dice 3 times--
#              Player B is currently moving....
#                  Player B moved from 18 to 28
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 4 times--
#              Player A is currently moving....
#                  Player A moved from 33 to 34
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 4 times--
#              Player B is currently moving....
#                  Player B moved from 28 to 32
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 5 times--
#              Player A is currently moving....
#                  Player A moved from 34 to 38
# Player B its your turn
#     Rolling dice...
#         You rolled a  14
# --Player B has rolled the dice 5 times--
#              Player B is currently moving....
#                  Player B moved from 32 to 46
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 6 times--
#              Player A is currently moving....
#                  Player A moved from 38 to 40
# Player B its your turn
#     Rolling dice...
#         You rolled a  14
# --Player B has rolled the dice 6 times--
#              Player B is currently moving....
#                  Player B moved from 46 to 60
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 7 times--
#              Player A is currently moving....
#                  Player A moved from 40 to 43
# Player B its your turn
#     Rolling dice...
#         You rolled a  14
# --Player B has rolled the dice 7 times--
#              Player B is currently moving....
#                  Player B moved from 60 to 74
# Player A its your turn
#     Rolling dice...
#         You rolled a  14
# --Player A has rolled the dice 8 times--
#              Player A is currently moving....
#                  Player A moved from 43 to 57
# Player B its your turn
#     Rolling dice...
#         You rolled a  11
# --Player B has rolled the dice 8 times--
#              Player B is currently moving....
#                  Player B moved from 74 to 85
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 9 times--
#              Player A is currently moving....
#                  Player A moved from 57 to 63
# Player B its your turn
#     Rolling dice...
#         You rolled a  9
# --Player B has rolled the dice 9 times--
#              Player B is currently moving....
#                  Player B moved from 85 to 94
# Player A its your turn
#     Rolling dice...
#         You rolled a  13
# --Player A has rolled the dice 10 times--
#              Player A is currently moving....
#                  Player A moved from 63 to 76
# Player B its your turn
#     Rolling dice...
#         You rolled a  12
# --Player B has rolled the dice 10 times--
#              Player B is currently moving....
# Unlucky, you need to roll a 6 to win the game so don't give up, keep rolling.
# Player A its your turn
#     Rolling dice...
#         You rolled a  12
# --Player A has rolled the dice 11 times--
#              Player A is currently moving....
#                  Player A moved from 76 to 88
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 11 times--
#              Player B is currently moving....
#                  Player B moved from 94 to 95
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 12 times--
#              Player A is currently moving....
#                  Player A moved from 88 to 89
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 12 times--
#              Player B is currently moving....
#                  Player B moved from 95 to 100
# Congrats Player B , you have won the game!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
assert snakes_and_ladders_check("Player A",10,3) == 13
print('---success---')
# Out:
#                  Player A moved from 10 to 13
# ---success---

# %%
# 2)

# %%
import random

# Using dictionaries to store the snakes and ladders on the board
# ladders move you up from the key to value
# Snakes move you down from the key to value
ladders = {7: 14,
    15: 21,
    20: 29,
    27: 31,
    35: 39,
    40: 54,
    63: 72,
    67: 80,
    70: 74,
    75: 90,}

snakes = {10: 2,
    12: 9,
    18: 13,
    26: 22,
    30: 28,
    39: 34,
    61: 55,
    73: 68,
    78: 69,
    99: 81,}

max_num = 100

def welcome_msg():
    """Start message explain the rules"""
    msg = """Welcome to Snakes and Ladders
    Rules:
    Two players
    Take turns to roll a six sided dice and move forward the number of positions shown on the dice
    Start at position 0
    The first player that reaches the final spot, 100, wins the game
    A cell on the board cannot contain both a snake and a ladder
    If you land at the bottom of the ladder you move to the top of the ladder
    If you land on the head of the snake you must slide down to the tail of the snake"""
    print(msg)

def player_name():
    """Establishing player name"""
    player_1_name = ("Player A")
    player_2_name = ("Player B")
    print(player_1_name, "vs", player_2_name)
    return player_1_name, player_2_name

def dice_num_roll():
    dice_num = random.randint(1, 6)
    print("        You rolled a ", str(dice_num))
    return dice_num

def snake_bite(old_num, curr_num, player_name):
    """When a player lands on a snake cell"""    
    print("Unfortunately, you have landed on a snake, please go down")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))

def ladder_climb(old_num, curr_num, player_name):
    """When a player lands on a ladder cell"""
    print("Wooo, you have landed on a ladder, please climb up")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))
    

def snakes_and_ladders_check(player_name, curr_num, dice_num):
    """A method that checks for the presence of snakes and ladders on the board"""
    old_num = curr_num
    curr_num = curr_num + dice_num
    
    if curr_num > max_num:
        print("Unlucky, you need to roll a", str(max_num - old_num), "to win the game so don't give up, keep rolling.")
        return old_num
    
    print("                ", player_name, "moved from", str(old_num), "to", str(curr_num))
    if curr_num in snakes:
        final_num = snakes.get(curr_num) # Returns the value of the specified key
        snake_bite(curr_num, final_num, player_name)        
    elif curr_num in ladders:
        final_num = ladders.get(curr_num)
        ladder_climb(curr_num, final_num, player_name)
    else:
        final_num = curr_num

    return final_num

def win_check(player_name, pos):
    """Checks if player has met the win criteria"""
    if max_num == pos:
        print("""Congrats""", player_name, """, you have won the game!""")
        raise SystemExit # to stop the code running thus ending the game 

def start_game():
    """The function to run the program and start the game"""
    welcome_msg()
    player_1_name, player_2_name = player_name()
    
    player_1_curr_pos = 0
    player_2_curr_pos = 0
    
    player_A_roll_count = 0
    player_B_roll_count = 0
    
    while True:
        print(player_1_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        player_A_roll_count = player_A_roll_count + 1
        print("--Player A has rolled the dice", player_A_roll_count, "times--")
        print("            ", player_1_name, "is currently moving....")
        player_1_curr_pos = snakes_and_ladders_check(player_1_name, player_1_curr_pos, dice_num)
        win_check(player_1_name, player_1_curr_pos)
        
        print(player_2_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        player_B_roll_count = player_B_roll_count + 1
        print("--Player B has rolled the dice", player_B_roll_count, "times--")
        print("            ", player_2_name, "is currently moving....")
        player_2_curr_pos = snakes_and_ladders_check(player_2_name, player_2_curr_pos, dice_num)
        win_check(player_2_name, player_2_curr_pos)       

start_game()
# Out:
# Welcome to Snakes and Ladders
#     Rules:
#     Two players
#     Take turns to roll a six sided dice and move forward the number of positions shown on the dice
#     Start at position 0
#     The first player that reaches the final spot, 100, wins the game
#     A cell on the board cannot contain both a snake and a ladder
#     If you land at the bottom of the ladder you move to the top of the ladder
#     If you land on the head of the snake you must slide down to the tail of the snake
# Player A vs Player B
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 1 times--
#              Player A is currently moving....
#                  Player A moved from 0 to 4
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 1 times--
#              Player B is currently moving....
#                  Player B moved from 0 to 5
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 2 times--
#              Player A is currently moving....
#                  Player A moved from 4 to 5
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 2 times--
#              Player B is currently moving....
#                  Player B moved from 5 to 10
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 10 to 2
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 3 times--
#              Player A is currently moving....
#                  Player A moved from 5 to 11
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 3 times--
#              Player B is currently moving....
#                  Player B moved from 2 to 5
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 4 times--
#              Player A is currently moving....
#                  Player A moved from 11 to 13
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 4 times--
#              Player B is currently moving....
#                  Player B moved from 5 to 11
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 5 times--
#              Player A is currently moving....
#                  Player A moved from 13 to 16
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 5 times--
#              Player B is currently moving....
#                  Player B moved from 11 to 15
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 15 to 21
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 6 times--
#              Player A is currently moving....
#                  Player A moved from 16 to 18
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 18 to 13
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 6 times--
#              Player B is currently moving....
#                  Player B moved from 21 to 23
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 7 times--
#              Player A is currently moving....
#                  Player A moved from 13 to 17
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 7 times--
#              Player B is currently moving....
#                  Player B moved from 23 to 26
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 26 to 22
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 8 times--
#              Player A is currently moving....
#                  Player A moved from 17 to 21
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 8 times--
#              Player B is currently moving....
#                  Player B moved from 22 to 26
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 26 to 22
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 9 times--
#              Player A is currently moving....
#                  Player A moved from 21 to 24
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 9 times--
#              Player B is currently moving....
#                  Player B moved from 22 to 24
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 10 times--
#              Player A is currently moving....
#                  Player A moved from 24 to 25
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 10 times--
#              Player B is currently moving....
#                  Player B moved from 24 to 26
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 26 to 22
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 11 times--
#              Player A is currently moving....
#                  Player A moved from 25 to 30
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 30 to 28
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 11 times--
#              Player B is currently moving....
#                  Player B moved from 22 to 23
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 12 times--
#              Player A is currently moving....
#                  Player A moved from 28 to 32
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 12 times--
#              Player B is currently moving....
#                  Player B moved from 23 to 29
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 13 times--
#              Player A is currently moving....
#                  Player A moved from 32 to 37
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 13 times--
#              Player B is currently moving....
#                  Player B moved from 29 to 33
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 14 times--
#              Player A is currently moving....
#                  Player A moved from 37 to 39
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 39 to 34
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 14 times--
#              Player B is currently moving....
#                  Player B moved from 33 to 36
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 15 times--
#              Player A is currently moving....
#                  Player A moved from 34 to 38
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 15 times--
#              Player B is currently moving....
#                  Player B moved from 36 to 40
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 40 to 54
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 16 times--
#              Player A is currently moving....
#                  Player A moved from 38 to 43
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 16 times--
#              Player B is currently moving....
#                  Player B moved from 54 to 59
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 17 times--
#              Player A is currently moving....
#                  Player A moved from 43 to 44
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 17 times--
#              Player B is currently moving....
#                  Player B moved from 59 to 60
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 18 times--
#              Player A is currently moving....
#                  Player A moved from 44 to 46
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 18 times--
#              Player B is currently moving....
#                  Player B moved from 60 to 64
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 19 times--
#              Player A is currently moving....
#                  Player A moved from 46 to 48
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 19 times--
#              Player B is currently moving....
#                  Player B moved from 64 to 65
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 20 times--
#              Player A is currently moving....
#                  Player A moved from 48 to 52
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 20 times--
#              Player B is currently moving....
#                  Player B moved from 65 to 66
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 21 times--
#              Player A is currently moving....
#                  Player A moved from 52 to 53
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 21 times--
#              Player B is currently moving....
#                  Player B moved from 66 to 72
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 22 times--
#              Player A is currently moving....
#                  Player A moved from 53 to 59
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 22 times--
#              Player B is currently moving....
#                  Player B moved from 72 to 75
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 75 to 90
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 23 times--
#              Player A is currently moving....
#                  Player A moved from 59 to 64
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 23 times--
#              Player B is currently moving....
#                  Player B moved from 90 to 93
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 24 times--
#              Player A is currently moving....
#                  Player A moved from 64 to 68
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 24 times--
#              Player B is currently moving....
#                  Player B moved from 93 to 96
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 25 times--
#              Player A is currently moving....
#                  Player A moved from 68 to 73
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 73 to 68
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 25 times--
#              Player B is currently moving....
#                  Player B moved from 96 to 99
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 99 to 81
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 26 times--
#              Player A is currently moving....
#                  Player A moved from 68 to 73
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 73 to 68
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 26 times--
#              Player B is currently moving....
#                  Player B moved from 81 to 85
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 27 times--
#              Player A is currently moving....
#                  Player A moved from 68 to 74
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 27 times--
#              Player B is currently moving....
#                  Player B moved from 85 to 86
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 28 times--
#              Player A is currently moving....
#                  Player A moved from 74 to 79
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 28 times--
#              Player B is currently moving....
#                  Player B moved from 86 to 92
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 29 times--
#              Player A is currently moving....
#                  Player A moved from 79 to 82
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 29 times--
#              Player B is currently moving....
#                  Player B moved from 92 to 96
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 30 times--
#              Player A is currently moving....
#                  Player A moved from 82 to 84
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 30 times--
#              Player B is currently moving....
# Unlucky, you need to roll a 4 to win the game so don't give up, keep rolling.
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 31 times--
#              Player A is currently moving....
#                  Player A moved from 84 to 85
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 31 times--
#              Player B is currently moving....
# Unlucky, you need to roll a 4 to win the game so don't give up, keep rolling.
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 32 times--
#              Player A is currently moving....
#                  Player A moved from 85 to 91
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 32 times--
#              Player B is currently moving....
#                  Player B moved from 96 to 97
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 33 times--
#              Player A is currently moving....
#                  Player A moved from 91 to 96
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 33 times--
#              Player B is currently moving....
# Unlucky, you need to roll a 3 to win the game so don't give up, keep rolling.
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 34 times--
#              Player A is currently moving....
#                  Player A moved from 96 to 99
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 99 to 81
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 34 times--
#              Player B is currently moving....
# Unlucky, you need to roll a 3 to win the game so don't give up, keep rolling.
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 35 times--
#              Player A is currently moving....
#                  Player A moved from 81 to 82
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 35 times--
#              Player B is currently moving....
# Unlucky, you need to roll a 3 to win the game so don't give up, keep rolling.
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 36 times--
#              Player A is currently moving....
#                  Player A moved from 82 to 84
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 36 times--
#              Player B is currently moving....
#                  Player B moved from 97 to 100
# Congrats Player B , you have won the game!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# 50 cell board

# %%
import random

# Using dictionaries to store the snakes and ladders on the board
# ladders move you up from the key to value
# Snakes move you down from the key to value
ladders = {7: 14,
    15: 21,
    20: 29,
    27: 31,
    35: 39,
    40: 49}
    
snakes = {10: 2,
    12: 9,
    18: 13,
    26: 22,
    30: 28,
    39: 34,
    }

max_num = 50

def welcome_msg():
    """Start message explain the rules"""
    msg = """Welcome to Snakes and Ladders
    Rules:
    Two players
    Take turns to roll a six sided dice and move forward the number of positions shown on the dice
    Start at position 0
    The first player that reaches the final spot, 100, wins the game
    A cell on the board cannot contain both a snake and a ladder
    If you land at the bottom of the ladder you move to the top of the ladder
    If you land on the head of the snake you must slide down to the tail of the snake"""
    print(msg)

def player_name():
    """Establishing player name"""
    player_1_name = ("Player A")
    player_2_name = ("Player B")
    print(player_1_name, "vs", player_2_name)
    return player_1_name, player_2_name

def dice_num_roll():
    dice_num = random.randint(1, 6)
    print("You rolled a ", str(dice_num))
    return dice_num

def snake_bite(old_num, curr_num, player_name):
    """When a player lands on a snake cell"""
    print("Unfortunately, you have landed on a snake, please go down")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))

def ladder_climb(old_num, curr_num, player_name):
    """When a player lands on a ladder cell"""
    print("Wooo, you have landed on a ladder, please climb up")
    print(player_name, "moved from", str(old_num), "to", str(curr_num)) 

def snakes_and_ladders_check(player_name, curr_num, dice_num):
    """A method that checks for the presence of snakes and ladders on the board"""
    old_num = curr_num
    curr_num = curr_num + dice_num

    if curr_num > max_num:
        print("Unlucky, you need to roll a", str(max_num - old_num), "to win the game so dont give up, keep rolling.")
        return old_num
    
    print(player_name, "moved from", str(old_num), "to", str(curr_num))
    if curr_num in snakes:
        final_num = snakes.get(curr_num) # Returns the value of the specified key
        snake_bite(curr_num, final_num, player_name)
    
    elif curr_num in ladders:
        final_num = ladders.get(curr_num)
        ladder_climb(curr_num, final_num, player_name)

    else:
        final_num = curr_num

    return final_num

def win_check(player_name, pos):
    """Checks if player has met the win criteria"""
    if max_num == pos: # needs to land on 50 win
        print("""Congrats""", player_name, """, you have won the game!""")
        raise SystemExit # to stop the code running thus ending the game

def start_game():
    """The function to run the program and start the game"""
    welcome_msg()
    player_1_name, player_2_name = player_name()
    
    player_1_curr_pos = 0
    player_2_curr_pos = 0
    
    player_A_roll_count = 0
    player_B_roll_count = 0
           
    while True:
        print(player_1_name + " its your turn")
        print("Rolling dice...")
        dice_num = dice_num_roll()
        player_A_roll_count = player_A_roll_count + 1
        print("--Player A has rolled the dice", player_A_roll_count, "times--")
        print(player_1_name, "is currently moving....")
        player_1_curr_pos = snakes_and_ladders_check(player_1_name, player_1_curr_pos, dice_num)
        win_check(player_1_name, player_1_curr_pos)
        
        print(player_2_name + " its your turn")
        print("Rolling dice...")
        dice_num = dice_num_roll()
        player_B_roll_count = player_B_roll_count + 1
        print("--Player B has rolled the dice", player_B_roll_count, "times--")
        print(player_2_name, "is currently moving....")
        player_2_curr_pos = snakes_and_ladders_check(player_2_name, player_2_curr_pos, dice_num)
        win_check(player_2_name, player_2_curr_pos)
        
start_game()
# Out:
# Welcome to Snakes and Ladders
#     Rules:
#     Two players
#     Take turns to roll a six sided dice and move forward the number of positions shown on the dice
#     Start at position 0
#     The first player that reaches the final spot, 100, wins the game
#     A cell on the board cannot contain both a snake and a ladder
#     If you land at the bottom of the ladder you move to the top of the ladder
#     If you land on the head of the snake you must slide down to the tail of the snake
# Player A vs Player B
# Player A its your turn
# Rolling dice...
# You rolled a  6
# --Player A has rolled the dice 1 times--
# Player A is currently moving....
# Player A moved from 0 to 6
# Player B its your turn
# Rolling dice...
# You rolled a  5
# --Player B has rolled the dice 1 times--
# Player B is currently moving....
# Player B moved from 0 to 5
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 2 times--
# Player A is currently moving....
# Player A moved from 6 to 10
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 10 to 2
# Player B its your turn
# Rolling dice...
# You rolled a  4
# --Player B has rolled the dice 2 times--
# Player B is currently moving....
# Player B moved from 5 to 9
# Player A its your turn
# Rolling dice...
# You rolled a  1
# --Player A has rolled the dice 3 times--
# Player A is currently moving....
# Player A moved from 2 to 3
# Player B its your turn
# Rolling dice...
# You rolled a  4
# --Player B has rolled the dice 3 times--
# Player B is currently moving....
# Player B moved from 9 to 13
# Player A its your turn
# Rolling dice...
# You rolled a  1
# --Player A has rolled the dice 4 times--
# Player A is currently moving....
# Player A moved from 3 to 4
# Player B its your turn
# Rolling dice...
# You rolled a  4
# --Player B has rolled the dice 4 times--
# Player B is currently moving....
# Player B moved from 13 to 17
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 5 times--
# Player A is currently moving....
# Player A moved from 4 to 6
# Player B its your turn
# Rolling dice...
# You rolled a  2
# --Player B has rolled the dice 5 times--
# Player B is currently moving....
# Player B moved from 17 to 19
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 6 times--
# Player A is currently moving....
# Player A moved from 6 to 10
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 10 to 2
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 6 times--
# Player B is currently moving....
# Player B moved from 19 to 20
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 20 to 29
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 7 times--
# Player A is currently moving....
# Player A moved from 2 to 6
# Player B its your turn
# Rolling dice...
# You rolled a  4
# --Player B has rolled the dice 7 times--
# Player B is currently moving....
# Player B moved from 29 to 33
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 8 times--
# Player A is currently moving....
# Player A moved from 6 to 10
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 10 to 2
# Player B its your turn
# Rolling dice...
# You rolled a  3
# --Player B has rolled the dice 8 times--
# Player B is currently moving....
# Player B moved from 33 to 36
# Player A its your turn
# Rolling dice...
# You rolled a  6
# --Player A has rolled the dice 9 times--
# Player A is currently moving....
# Player A moved from 2 to 8
# Player B its your turn
# Rolling dice...
# You rolled a  4
# --Player B has rolled the dice 9 times--
# Player B is currently moving....
# Player B moved from 36 to 40
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 40 to 49
# Player A its your turn
# Rolling dice...
# You rolled a  1
# --Player A has rolled the dice 10 times--
# Player A is currently moving....
# Player A moved from 8 to 9
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 10 times--
# Player B is currently moving....
# Unlucky, you need to roll a 1 to win the game so dont give up, keep rolling.
# Player A its your turn
# Rolling dice...
# You rolled a  5
# --Player A has rolled the dice 11 times--
# Player A is currently moving....
# Player A moved from 9 to 14
# Player B its your turn
# Rolling dice...
# You rolled a  3
# --Player B has rolled the dice 11 times--
# Player B is currently moving....
# Unlucky, you need to roll a 1 to win the game so dont give up, keep rolling.
# Player A its your turn
# Rolling dice...
# You rolled a  5
# --Player A has rolled the dice 12 times--
# Player A is currently moving....
# Player A moved from 14 to 19
# Player B its your turn
# Rolling dice...
# You rolled a  5
# --Player B has rolled the dice 12 times--
# Player B is currently moving....
# Unlucky, you need to roll a 1 to win the game so dont give up, keep rolling.
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 13 times--
# Player A is currently moving....
# Player A moved from 19 to 21
# Player B its your turn
# Rolling dice...
# You rolled a  3
# --Player B has rolled the dice 13 times--
# Player B is currently moving....
# Unlucky, you need to roll a 1 to win the game so dont give up, keep rolling.
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 14 times--
# Player A is currently moving....
# Player A moved from 21 to 25
# Player B its your turn
# Rolling dice...
# You rolled a  3
# --Player B has rolled the dice 14 times--
# Player B is currently moving....
# Unlucky, you need to roll a 1 to win the game so dont give up, keep rolling.
# Player A its your turn
# Rolling dice...
# You rolled a  3
# --Player A has rolled the dice 15 times--
# Player A is currently moving....
# Player A moved from 25 to 28
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 15 times--
# Player B is currently moving....
# Unlucky, you need to roll a 1 to win the game so dont give up, keep rolling.
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 16 times--
# Player A is currently moving....
# Player A moved from 28 to 30
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 30 to 28
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 16 times--
# Player B is currently moving....
# Player B moved from 49 to 50
# Congrats Player B , you have won the game!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3333: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# Can pass 100

# %%
import random

# Using dictionaries to store the snakes and ladders on the board
# ladders move you up from the key to value
# Snakes move you down from the key to value
ladders = {7: 14,
    15: 21,
    20: 29,
    27: 31,
    35: 39,
    40: 54,
    63: 72,
    67: 80,
    70: 74,
    75: 90,}

snakes = {10: 2,
    12: 9,
    18: 13,
    26: 22,
    30: 28,
    39: 34,
    61: 55,
    73: 68,
    78: 69,
    99: 81,}

max_num = 100


def welcome_msg():
    """Start of game message with rules"""
    msg = """Welcome to Snakes and Ladders
    Rules:
    Two players
    Take turns to roll a six sided dice and move forward the number of positions shown on the dice
    Start at position 0
    The first player that reaches the final spot, 100, wins the game
    A cell on the board cannot contain both a snake and a ladder
    If you land at the bottom of the ladder you move to the top of the ladder
    If you land on the head of the snake you must slide down to the tail of the snake"""
    print(msg)

def player_name():
    """Establishing player name"""
    player_1_name = ("Player A")
    player_2_name = ("Player B")
    print(player_1_name, "vs", player_2_name)
    return player_1_name, player_2_name

def dice_num_roll():
    dice_num = random.randint(1, 6)
    print("You rolled a ", str(dice_num))
    return dice_num

def snake_bite(old_num, curr_num, player_name):
    """When a player lands on a snake cell"""
    print("Unfortunately, you have landed on a snake, please go down")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))

def ladder_climb(old_num, curr_num, player_name):
    """When a player lands on a ladder cell"""
    print("Wooo, you have landed on a ladder, please climb up")
    print(player_name, "moved from", str(old_num), "to", str(curr_num)) 

def snakes_and_ladders_check(player_name, curr_num, dice_num):
    """A method that checks for the presence of snakes and ladders on the board"""
    old_num = curr_num
    curr_num = curr_num + dice_num
    
    print(player_name, "moved from", str(old_num), "to", str(curr_num))
    if curr_num in snakes:
        final_num = snakes.get(curr_num) # Returns the value of the specified key
        snake_bite(curr_num, final_num, player_name)
    
    elif curr_num in ladders:
        final_num = ladders.get(curr_num)
        ladder_climb(curr_num, final_num, player_name)

    else:
        final_num = curr_num

    return final_num

def win_check(player_name, pos):
    """Checks if player has met the win criteria"""
    if max_num <= pos:
        print("""Congrats""", player_name, """, you have won the game!""")
        raise SystemExit # to stop the code running thus ending the game

def start_game():
    """The function to run the program and start the game"""
    welcome_msg()
    player_1_name, player_2_name = player_name()
    
    player_1_curr_pos = 0
    player_2_curr_pos = 0

    player_A_roll_count = 0
    player_B_roll_count = 0
    
    while True:
        print(player_1_name + " its your turn")
        print("Rolling dice...")
        dice_num = dice_num_roll()
        player_A_roll_count = player_A_roll_count + 1
        print("--Player A has rolled the dice", player_A_roll_count, "times--")
        print(player_1_name, "is currently moving....")
        player_1_curr_pos = snakes_and_ladders_check(player_1_name, player_1_curr_pos, dice_num)
        win_check(player_1_name, player_1_curr_pos)
        
        print(player_2_name + " its your turn")
        print("Rolling dice...")
        dice_num = dice_num_roll()
        player_B_roll_count = player_B_roll_count + 1
        print("--Player B has rolled the dice", player_B_roll_count, "times--")
        print(player_2_name, "is currently moving....")
        player_2_curr_pos = snakes_and_ladders_check(player_2_name, player_2_curr_pos, dice_num)
        win_check(player_2_name, player_2_curr_pos)
        
start_game()
# Out:
# Welcome to Snakes and Ladders
#     Rules:
#     Two players
#     Take turns to roll a six sided dice and move forward the number of positions shown on the dice
#     Start at position 0
#     The first player that reaches the final spot, 100, wins the game
#     A cell on the board cannot contain both a snake and a ladder
#     If you land at the bottom of the ladder you move to the top of the ladder
#     If you land on the head of the snake you must slide down to the tail of the snake
# Player A vs Player B
# Player A its your turn
# Rolling dice...
# You rolled a  6
# --Player A has rolled the dice 1 times--
# Player A is currently moving....
# Player A moved from 0 to 6
# Player B its your turn
# Rolling dice...
# You rolled a  3
# --Player B has rolled the dice 1 times--
# Player B is currently moving....
# Player B moved from 0 to 3
# Player A its your turn
# Rolling dice...
# You rolled a  1
# --Player A has rolled the dice 2 times--
# Player A is currently moving....
# Player A moved from 6 to 7
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 7 to 14
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 2 times--
# Player B is currently moving....
# Player B moved from 3 to 4
# Player A its your turn
# Rolling dice...
# You rolled a  1
# --Player A has rolled the dice 3 times--
# Player A is currently moving....
# Player A moved from 14 to 15
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 15 to 21
# Player B its your turn
# Rolling dice...
# You rolled a  2
# --Player B has rolled the dice 3 times--
# Player B is currently moving....
# Player B moved from 4 to 6
# Player A its your turn
# Rolling dice...
# You rolled a  5
# --Player A has rolled the dice 4 times--
# Player A is currently moving....
# Player A moved from 21 to 26
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 26 to 22
# Player B its your turn
# Rolling dice...
# You rolled a  5
# --Player B has rolled the dice 4 times--
# Player B is currently moving....
# Player B moved from 6 to 11
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 5 times--
# Player A is currently moving....
# Player A moved from 22 to 24
# Player B its your turn
# Rolling dice...
# You rolled a  3
# --Player B has rolled the dice 5 times--
# Player B is currently moving....
# Player B moved from 11 to 14
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 6 times--
# Player A is currently moving....
# Player A moved from 24 to 26
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 26 to 22
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 6 times--
# Player B is currently moving....
# Player B moved from 14 to 20
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 20 to 29
# Player A its your turn
# Rolling dice...
# You rolled a  5
# --Player A has rolled the dice 7 times--
# Player A is currently moving....
# Player A moved from 22 to 27
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 27 to 31
# Player B its your turn
# Rolling dice...
# You rolled a  5
# --Player B has rolled the dice 7 times--
# Player B is currently moving....
# Player B moved from 29 to 34
# Player A its your turn
# Rolling dice...
# You rolled a  6
# --Player A has rolled the dice 8 times--
# Player A is currently moving....
# Player A moved from 31 to 37
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 8 times--
# Player B is currently moving....
# Player B moved from 34 to 35
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 35 to 39
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 9 times--
# Player A is currently moving....
# Player A moved from 37 to 39
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 39 to 34
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 9 times--
# Player B is currently moving....
# Player B moved from 39 to 45
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 10 times--
# Player A is currently moving....
# Player A moved from 34 to 36
# Player B its your turn
# Rolling dice...
# You rolled a  5
# --Player B has rolled the dice 10 times--
# Player B is currently moving....
# Player B moved from 45 to 50
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 11 times--
# Player A is currently moving....
# Player A moved from 36 to 40
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 40 to 54
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 11 times--
# Player B is currently moving....
# Player B moved from 50 to 56
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 12 times--
# Player A is currently moving....
# Player A moved from 54 to 56
# Player B its your turn
# Rolling dice...
# You rolled a  2
# --Player B has rolled the dice 12 times--
# Player B is currently moving....
# Player B moved from 56 to 58
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 13 times--
# Player A is currently moving....
# Player A moved from 56 to 60
# Player B its your turn
# Rolling dice...
# You rolled a  2
# --Player B has rolled the dice 13 times--
# Player B is currently moving....
# Player B moved from 58 to 60
# Player A its your turn
# Rolling dice...
# You rolled a  1
# --Player A has rolled the dice 14 times--
# Player A is currently moving....
# Player A moved from 60 to 61
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 61 to 55
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 14 times--
# Player B is currently moving....
# Player B moved from 60 to 61
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 61 to 55
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 15 times--
# Player A is currently moving....
# Player A moved from 55 to 57
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 15 times--
# Player B is currently moving....
# Player B moved from 55 to 61
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 61 to 55
# Player A its your turn
# Rolling dice...
# You rolled a  5
# --Player A has rolled the dice 16 times--
# Player A is currently moving....
# Player A moved from 57 to 62
# Player B its your turn
# Rolling dice...
# You rolled a  3
# --Player B has rolled the dice 16 times--
# Player B is currently moving....
# Player B moved from 55 to 58
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 17 times--
# Player A is currently moving....
# Player A moved from 62 to 66
# Player B its your turn
# Rolling dice...
# You rolled a  2
# --Player B has rolled the dice 17 times--
# Player B is currently moving....
# Player B moved from 58 to 60
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 18 times--
# Player A is currently moving....
# Player A moved from 66 to 68
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 18 times--
# Player B is currently moving....
# Player B moved from 60 to 61
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 61 to 55
# Player A its your turn
# Rolling dice...
# You rolled a  3
# --Player A has rolled the dice 19 times--
# Player A is currently moving....
# Player A moved from 68 to 71
# Player B its your turn
# Rolling dice...
# You rolled a  2
# --Player B has rolled the dice 19 times--
# Player B is currently moving....
# Player B moved from 55 to 57
# Player A its your turn
# Rolling dice...
# You rolled a  3
# --Player A has rolled the dice 20 times--
# Player A is currently moving....
# Player A moved from 71 to 74
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 20 times--
# Player B is currently moving....
# Player B moved from 57 to 63
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 63 to 72
# Player A its your turn
# Rolling dice...
# You rolled a  1
# --Player A has rolled the dice 21 times--
# Player A is currently moving....
# Player A moved from 74 to 75
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 75 to 90
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 21 times--
# Player B is currently moving....
# Player B moved from 72 to 78
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 78 to 69
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 22 times--
# Player A is currently moving....
# Player A moved from 90 to 92
# Player B its your turn
# Rolling dice...
# You rolled a  5
# --Player B has rolled the dice 22 times--
# Player B is currently moving....
# Player B moved from 69 to 74
# Player A its your turn
# Rolling dice...
# You rolled a  5
# --Player A has rolled the dice 23 times--
# Player A is currently moving....
# Player A moved from 92 to 97
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 23 times--
# Player B is currently moving....
# Player B moved from 74 to 75
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 75 to 90
# Player A its your turn
# Rolling dice...
# You rolled a  2
# --Player A has rolled the dice 24 times--
# Player A is currently moving....
# Player A moved from 97 to 99
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 99 to 81
# Player B its your turn
# Rolling dice...
# You rolled a  6
# --Player B has rolled the dice 24 times--
# Player B is currently moving....
# Player B moved from 90 to 96
# Player A its your turn
# Rolling dice...
# You rolled a  6
# --Player A has rolled the dice 25 times--
# Player A is currently moving....
# Player A moved from 81 to 87
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 25 times--
# Player B is currently moving....
# Player B moved from 96 to 97
# Player A its your turn
# Rolling dice...
# You rolled a  4
# --Player A has rolled the dice 26 times--
# Player A is currently moving....
# Player A moved from 87 to 91
# Player B its your turn
# Rolling dice...
# You rolled a  1
# --Player B has rolled the dice 26 times--
# Player B is currently moving....
# Player B moved from 97 to 98
# Player A its your turn
# Rolling dice...
# You rolled a  1
# --Player A has rolled the dice 27 times--
# Player A is currently moving....
# Player A moved from 91 to 92
# Player B its your turn
# Rolling dice...
# You rolled a  4
# --Player B has rolled the dice 27 times--
# Player B is currently moving....
# Player B moved from 98 to 102
# Congrats Player B , you have won the game!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# 100 board with less snakes and ladders

# %%
import random

# Using dictionaries to store the snakes and ladders on the board
# ladders move you up from the key to value
# Snakes move you down from the key to value
ladders = {7: 14,
    15: 21,
    27: 31,
    63: 72,
    75: 90,}

snakes = {10: 2,
    12: 9,
    18: 13,
    73: 68,
    99: 81,}

max_num = 100

def welcome_msg():
    """Start message explain the rules"""
    msg = """Welcome to Snakes and Ladders
    Rules:
    Two players
    Take turns to roll a six sided dice and move forward the number of positions shown on the dice
    Start at position 0
    The first player that reaches the final spot, 100, wins the game
    A cell on the board cannot contain both a snake and a ladder
    If you land at the bottom of the ladder you move to the top of the ladder
    If you land on the head of the snake you must slide down to the tail of the snake"""
    print(msg)
    
def player_name():
    """Establishing player name"""
    player_1_name = ("Player A")
    player_2_name = ("Player B")
    print(player_1_name, "vs", player_2_name)
    return player_1_name, player_2_name

def dice_num_roll():
    dice_num = random.randint(1, 6)
    print("        You rolled a ", str(dice_num))
    return dice_num

def snake_bite(old_num, curr_num, player_name):
    """When a player lands on a snake cell"""
    print("Unfortunately, you have landed on a snake, please go down")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))

def ladder_climb(old_num, curr_num, player_name):
    """When a player lands on a ladder cell"""
    print("Wooo, you have landed on a ladder, please climb up")
    print(player_name, "moved from", str(old_num), "to", str(curr_num)) 

def snakes_and_ladders_check(player_name, curr_num, dice_num):
    """A method that checks for the presence of snakes and ladders on the board"""
    old_num = curr_num
    curr_num = curr_num + dice_num
    
    if curr_num > max_num:
        print("Unlucky, you need to roll a", str(max_num - old_num), "to win the game so dont give up, keep rolling.")
        return old_num
    
    print("                ", player_name, "moved from", str(old_num), "to", str(curr_num))
    if curr_num in snakes:
        final_num = snakes.get(curr_num) # Returns the value of the specified key
        snake_bite(curr_num, final_num, player_name)
    
    elif curr_num in ladders:
        final_num = ladders.get(curr_num)
        ladder_climb(curr_num, final_num, player_name)

    else:
        final_num = curr_num

    return final_num

def win_check(player_name, pos):
    """Checks if player has met the win criteria"""
    if max_num == pos:
        print("""Congrats""", player_name, """, you have won the game!""")
        raise SystemExit # to stop the code running thus ending the game

def start_game():
    """The function to run the program and start the game"""
    welcome_msg()
    player_1_name, player_2_name = player_name()
    
    player_1_curr_pos = 0
    player_2_curr_pos = 0
    
    player_A_roll_count = 0
    player_B_roll_count = 0
    
    while True:
        print(player_1_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        player_A_roll_count = player_A_roll_count + 1
        print("--Player A has rolled the dice", player_A_roll_count, "times--")
        print("            ", player_1_name, "is currently moving....")
        player_1_curr_pos = snakes_and_ladders_check(player_1_name, player_1_curr_pos, dice_num)
        win_check(player_1_name, player_1_curr_pos)
        
        print(player_2_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        player_B_roll_count = player_B_roll_count + 1
        print("--Player B has rolled the dice", player_B_roll_count, "times--")
        print("            ", player_2_name, "is currently moving....")
        player_2_curr_pos = snakes_and_ladders_check(player_2_name, player_2_curr_pos, dice_num)
        win_check(player_2_name, player_2_curr_pos)
        
start_game()
# Out:
# Welcome to Snakes and Ladders
#     Rules:
#     Two players
#     Take turns to roll a six sided dice and move forward the number of positions shown on the dice
#     Start at position 0
#     The first player that reaches the final spot, 100, wins the game
#     A cell on the board cannot contain both a snake and a ladder
#     If you land at the bottom of the ladder you move to the top of the ladder
#     If you land on the head of the snake you must slide down to the tail of the snake
# Player A vs Player B
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 1 times--
#              Player A is currently moving....
#                  Player A moved from 0 to 6
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 1 times--
#              Player B is currently moving....
#                  Player B moved from 0 to 4
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 2 times--
#              Player A is currently moving....
#                  Player A moved from 6 to 11
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 2 times--
#              Player B is currently moving....
#                  Player B moved from 4 to 10
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 10 to 2
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 3 times--
#              Player A is currently moving....
#                  Player A moved from 11 to 13
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 3 times--
#              Player B is currently moving....
#                  Player B moved from 2 to 6
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 4 times--
#              Player A is currently moving....
#                  Player A moved from 13 to 18
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 18 to 13
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 4 times--
#              Player B is currently moving....
#                  Player B moved from 6 to 11
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 5 times--
#              Player A is currently moving....
#                  Player A moved from 13 to 15
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 15 to 21
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 5 times--
#              Player B is currently moving....
#                  Player B moved from 11 to 13
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 6 times--
#              Player A is currently moving....
#                  Player A moved from 21 to 22
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 6 times--
#              Player B is currently moving....
#                  Player B moved from 13 to 19
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 7 times--
#              Player A is currently moving....
#                  Player A moved from 22 to 23
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 7 times--
#              Player B is currently moving....
#                  Player B moved from 19 to 24
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 8 times--
#              Player A is currently moving....
#                  Player A moved from 23 to 26
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 8 times--
#              Player B is currently moving....
#                  Player B moved from 24 to 25
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 9 times--
#              Player A is currently moving....
#                  Player A moved from 26 to 30
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 9 times--
#              Player B is currently moving....
#                  Player B moved from 25 to 26
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 10 times--
#              Player A is currently moving....
#                  Player A moved from 30 to 32
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 10 times--
#              Player B is currently moving....
#                  Player B moved from 26 to 27
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 27 to 31
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 11 times--
#              Player A is currently moving....
#                  Player A moved from 32 to 34
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 11 times--
#              Player B is currently moving....
#                  Player B moved from 31 to 36
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 12 times--
#              Player A is currently moving....
#                  Player A moved from 34 to 40
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 12 times--
#              Player B is currently moving....
#                  Player B moved from 36 to 41
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 13 times--
#              Player A is currently moving....
#                  Player A moved from 40 to 45
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 13 times--
#              Player B is currently moving....
#                  Player B moved from 41 to 42
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 14 times--
#              Player A is currently moving....
#                  Player A moved from 45 to 51
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 14 times--
#              Player B is currently moving....
#                  Player B moved from 42 to 44
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 15 times--
#              Player A is currently moving....
#                  Player A moved from 51 to 52
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 15 times--
#              Player B is currently moving....
#                  Player B moved from 44 to 47
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 16 times--
#              Player A is currently moving....
#                  Player A moved from 52 to 56
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 16 times--
#              Player B is currently moving....
#                  Player B moved from 47 to 50
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 17 times--
#              Player A is currently moving....
#                  Player A moved from 56 to 62
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 17 times--
#              Player B is currently moving....
#                  Player B moved from 50 to 54
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 18 times--
#              Player A is currently moving....
#                  Player A moved from 62 to 63
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 63 to 72
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 18 times--
#              Player B is currently moving....
#                  Player B moved from 54 to 60
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 19 times--
#              Player A is currently moving....
#                  Player A moved from 72 to 74
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 19 times--
#              Player B is currently moving....
#                  Player B moved from 60 to 62
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 20 times--
#              Player A is currently moving....
#                  Player A moved from 74 to 80
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 20 times--
#              Player B is currently moving....
#                  Player B moved from 62 to 65
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 21 times--
#              Player A is currently moving....
#                  Player A moved from 80 to 81
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 21 times--
#              Player B is currently moving....
#                  Player B moved from 65 to 68
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 22 times--
#              Player A is currently moving....
#                  Player A moved from 81 to 85
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 22 times--
#              Player B is currently moving....
#                  Player B moved from 68 to 73
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 73 to 68
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 23 times--
#              Player A is currently moving....
#                  Player A moved from 85 to 89
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 23 times--
#              Player B is currently moving....
#                  Player B moved from 68 to 70
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 24 times--
#              Player A is currently moving....
#                  Player A moved from 89 to 90
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 24 times--
#              Player B is currently moving....
#                  Player B moved from 70 to 73
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 73 to 68
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 25 times--
#              Player A is currently moving....
#                  Player A moved from 90 to 96
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 25 times--
#              Player B is currently moving....
#                  Player B moved from 68 to 73
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 73 to 68
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 26 times--
#              Player A is currently moving....
# Unlucky, you need to roll a 4 to win the game so dont give up, keep rolling.
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 26 times--
#              Player B is currently moving....
#                  Player B moved from 68 to 70
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 27 times--
#              Player A is currently moving....
# Unlucky, you need to roll a 4 to win the game so dont give up, keep rolling.
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 27 times--
#              Player B is currently moving....
#                  Player B moved from 70 to 72
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 28 times--
#              Player A is currently moving....
#                  Player A moved from 96 to 100
# Congrats Player A , you have won the game!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# bounce back version

# %%
import random

# Using dictionaries to store the snakes and ladders on the board
# ladders move you up from the key to value
# Snakes move you down from the key to value
ladders = {7: 14,
    15: 21,
    20: 29,
    27: 31,
    35: 39,
    40: 54,
    63: 72,
    67: 80,
    70: 74,
    75: 90,}

snakes = {10: 2,
    12: 9,
    18: 13,
    26: 22,
    30: 28,
    39: 34,
    61: 55,
    73: 68,
    78: 69,
    99: 81,}

max_num = 100

def welcome_msg():
    """Start message explain the rules"""
    msg = """Welcome to Snakes and Ladders
    Rules:
    Two players
    Take turns to roll a six sided dice and move forward the number of positions shown on the dice
    Start at position 0
    The first player that reaches the final spot, 100, wins the game
    A cell on the board cannot contain both a snake and a ladder
    If you land at the bottom of the ladder you move to the top of the ladder
    If you land on the head of the snake you must slide down to the tail of the snake"""
    print(msg)

def player_name():
    """Establishing player name"""
    player_1_name = ("Player A")
    player_2_name = ("Player B")
    print(player_1_name, "vs", player_2_name)
    return player_1_name, player_2_name

def dice_num_roll():
    dice_num = random.randint(1, 6)
    print("        You rolled a ", str(dice_num))
    return dice_num

def snake_bite(old_num, curr_num, player_name):
    """When a player lands on a snake cell"""
    print("Unfortunately, you have landed on a snake, please go down")
    print(player_name, "moved from", str(old_num), "to", str(curr_num))

def ladder_climb(old_num, curr_num, player_name):
    """When a player lands on a ladder cell"""
    print("Wooo, you have landed on a ladder, please climb up")
    print(player_name, "moved from", str(old_num), "to", str(curr_num)) 

def snakes_and_ladders_check(player_name, curr_num, dice_num):
    """A method that checks for the presence of snakes and ladders on the board"""
    old_num = curr_num
    curr_num = curr_num + dice_num
    
    if curr_num > max_num:
        final_num = (max_num - (curr_num - max_num))
        print("                ", player_name, "moved from", str(old_num), "to", str(final_num), "after going over", str(max_num), "and bouncing back")
        print("Unlucky, you need to roll a", str(max_num - final_num), "to win the game so dont give up, keep rolling.")
        return final_num
    
    print("                ", player_name, "moved from", str(old_num), "to", str(curr_num))
    if curr_num in snakes:
        final_num = snakes.get(curr_num) # Returns the value of the specified key
        snake_bite(curr_num, final_num, player_name)
    
    elif curr_num in ladders:
        final_num = ladders.get(curr_num)
        ladder_climb(curr_num, final_num, player_name)

    else:
        final_num = curr_num

    return final_num

def win_check(player_name, pos):
    """Checks if player has met the win criteria"""
    if max_num == pos:
        print("""Congrats""", player_name, """, you have won the game!""")
        raise SystemExit # to stop the code running thus ending the game

def start_game():
    """The function to run the program and start the game"""
    welcome_msg()
    player_1_name, player_2_name = player_name()
    
    player_1_curr_pos = 0
    player_2_curr_pos = 0
    
    player_A_roll_count = 0
    player_B_roll_count = 0
    
    while True:
        print(player_1_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        player_A_roll_count = player_A_roll_count + 1
        print("--Player A has rolled the dice", player_A_roll_count, "times--")
        print("            ", player_1_name, "is currently moving....")
        player_1_curr_pos = snakes_and_ladders_check(player_1_name, player_1_curr_pos, dice_num)
        win_check(player_1_name, player_1_curr_pos)
        
        print(player_2_name + " its your turn")
        print("    Rolling dice...")
        dice_num = dice_num_roll()
        player_B_roll_count = player_B_roll_count + 1
        print("--Player B has rolled the dice", player_B_roll_count, "times--")
        print("            ", player_2_name, "is currently moving....")
        player_2_curr_pos = snakes_and_ladders_check(player_2_name, player_2_curr_pos, dice_num)
        win_check(player_2_name, player_2_curr_pos)
        
start_game()
# Out:
# Welcome to Snakes and Ladders
#     Rules:
#     Two players
#     Take turns to roll a six sided dice and move forward the number of positions shown on the dice
#     Start at position 0
#     The first player that reaches the final spot, 100, wins the game
#     A cell on the board cannot contain both a snake and a ladder
#     If you land at the bottom of the ladder you move to the top of the ladder
#     If you land on the head of the snake you must slide down to the tail of the snake
# Player A vs Player B
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 1 times--
#              Player A is currently moving....
#                  Player A moved from 0 to 2
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 1 times--
#              Player B is currently moving....
#                  Player B moved from 0 to 5
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 2 times--
#              Player A is currently moving....
#                  Player A moved from 2 to 8
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 2 times--
#              Player B is currently moving....
#                  Player B moved from 5 to 6
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 3 times--
#              Player A is currently moving....
#                  Player A moved from 8 to 14
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 3 times--
#              Player B is currently moving....
#                  Player B moved from 6 to 7
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 7 to 14
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 4 times--
#              Player A is currently moving....
#                  Player A moved from 14 to 18
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 18 to 13
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 4 times--
#              Player B is currently moving....
#                  Player B moved from 14 to 15
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 15 to 21
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 5 times--
#              Player A is currently moving....
#                  Player A moved from 13 to 18
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 18 to 13
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 5 times--
#              Player B is currently moving....
#                  Player B moved from 21 to 24
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 6 times--
#              Player A is currently moving....
#                  Player A moved from 13 to 16
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 6 times--
#              Player B is currently moving....
#                  Player B moved from 24 to 25
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 7 times--
#              Player A is currently moving....
#                  Player A moved from 16 to 17
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 7 times--
#              Player B is currently moving....
#                  Player B moved from 25 to 26
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 26 to 22
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 8 times--
#              Player A is currently moving....
#                  Player A moved from 17 to 23
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 8 times--
#              Player B is currently moving....
#                  Player B moved from 22 to 28
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 9 times--
#              Player A is currently moving....
#                  Player A moved from 23 to 24
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 9 times--
#              Player B is currently moving....
#                  Player B moved from 28 to 30
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 30 to 28
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 10 times--
#              Player A is currently moving....
#                  Player A moved from 24 to 26
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 26 to 22
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 10 times--
#              Player B is currently moving....
#                  Player B moved from 28 to 32
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 11 times--
#              Player A is currently moving....
#                  Player A moved from 22 to 28
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 11 times--
#              Player B is currently moving....
#                  Player B moved from 32 to 38
# Player A its your turn
#     Rolling dice...
#         You rolled a  2
# --Player A has rolled the dice 12 times--
#              Player A is currently moving....
#                  Player A moved from 28 to 30
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 30 to 28
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 12 times--
#              Player B is currently moving....
#                  Player B moved from 38 to 40
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 40 to 54
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 13 times--
#              Player A is currently moving....
#                  Player A moved from 28 to 29
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 13 times--
#              Player B is currently moving....
#                  Player B moved from 54 to 55
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 14 times--
#              Player A is currently moving....
#                  Player A moved from 29 to 34
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 14 times--
#              Player B is currently moving....
#                  Player B moved from 55 to 58
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 15 times--
#              Player A is currently moving....
#                  Player A moved from 34 to 39
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 39 to 34
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 15 times--
#              Player B is currently moving....
#                  Player B moved from 58 to 63
# Wooo, you have landed on a ladder, please climb up
# Player B moved from 63 to 72
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 16 times--
#              Player A is currently moving....
#                  Player A moved from 34 to 39
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 39 to 34
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 16 times--
#              Player B is currently moving....
#                  Player B moved from 72 to 76
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 17 times--
#              Player A is currently moving....
#                  Player A moved from 34 to 40
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 40 to 54
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 17 times--
#              Player B is currently moving....
#                  Player B moved from 76 to 82
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 18 times--
#              Player A is currently moving....
#                  Player A moved from 54 to 55
# Player B its your turn
#     Rolling dice...
#         You rolled a  3
# --Player B has rolled the dice 18 times--
#              Player B is currently moving....
#                  Player B moved from 82 to 85
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 19 times--
#              Player A is currently moving....
#                  Player A moved from 55 to 58
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 19 times--
#              Player B is currently moving....
#                  Player B moved from 85 to 90
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 20 times--
#              Player A is currently moving....
#                  Player A moved from 58 to 61
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 61 to 55
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 20 times--
#              Player B is currently moving....
#                  Player B moved from 90 to 91
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 21 times--
#              Player A is currently moving....
#                  Player A moved from 55 to 56
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 21 times--
#              Player B is currently moving....
#                  Player B moved from 91 to 93
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 22 times--
#              Player A is currently moving....
#                  Player A moved from 56 to 57
# Player B its your turn
#     Rolling dice...
#         You rolled a  4
# --Player B has rolled the dice 22 times--
#              Player B is currently moving....
#                  Player B moved from 93 to 97
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 23 times--
#              Player A is currently moving....
#                  Player A moved from 57 to 63
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 63 to 72
# Player B its your turn
#     Rolling dice...
#         You rolled a  6
# --Player B has rolled the dice 23 times--
#              Player B is currently moving....
#                  Player B moved from 97 to 97 after going over 100 and bouncing back
# Unlucky, you need to roll a 3 to win the game so dont give up, keep rolling.
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 24 times--
#              Player A is currently moving....
#                  Player A moved from 72 to 73
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 73 to 68
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 24 times--
#              Player B is currently moving....
#                  Player B moved from 97 to 99
# Unfortunately, you have landed on a snake, please go down
# Player B moved from 99 to 81
# Player A its your turn
#     Rolling dice...
#         You rolled a  3
# --Player A has rolled the dice 25 times--
#              Player A is currently moving....
#                  Player A moved from 68 to 71
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 25 times--
#              Player B is currently moving....
#                  Player B moved from 81 to 83
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 26 times--
#              Player A is currently moving....
#                  Player A moved from 71 to 75
# Wooo, you have landed on a ladder, please climb up
# Player A moved from 75 to 90
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 26 times--
#              Player B is currently moving....
#                  Player B moved from 83 to 84
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 27 times--
#              Player A is currently moving....
#                  Player A moved from 90 to 96
# Player B its your turn
#     Rolling dice...
#         You rolled a  2
# --Player B has rolled the dice 27 times--
#              Player B is currently moving....
#                  Player B moved from 84 to 86
# Player A its your turn
#     Rolling dice...
#         You rolled a  6
# --Player A has rolled the dice 28 times--
#              Player A is currently moving....
#                  Player A moved from 96 to 98 after going over 100 and bouncing back
# Unlucky, you need to roll a 2 to win the game so dont give up, keep rolling.
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 28 times--
#              Player B is currently moving....
#                  Player B moved from 86 to 91
# Player A its your turn
#     Rolling dice...
#         You rolled a  1
# --Player A has rolled the dice 29 times--
#              Player A is currently moving....
#                  Player A moved from 98 to 99
# Unfortunately, you have landed on a snake, please go down
# Player A moved from 99 to 81
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 29 times--
#              Player B is currently moving....
#                  Player B moved from 91 to 96
# Player A its your turn
#     Rolling dice...
#         You rolled a  5
# --Player A has rolled the dice 30 times--
#              Player A is currently moving....
#                  Player A moved from 81 to 86
# Player B its your turn
#     Rolling dice...
#         You rolled a  5
# --Player B has rolled the dice 30 times--
#              Player B is currently moving....
#                  Player B moved from 96 to 99 after going over 100 and bouncing back
# Unlucky, you need to roll a 1 to win the game so dont give up, keep rolling.
# Player A its your turn
#     Rolling dice...
#         You rolled a  4
# --Player A has rolled the dice 31 times--
#              Player A is currently moving....
#                  Player A moved from 86 to 90
# Player B its your turn
#     Rolling dice...
#         You rolled a  1
# --Player B has rolled the dice 31 times--
#              Player B is currently moving....
#                  Player B moved from 99 to 100
# Congrats Player B , you have won the game!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
